# %%
# !pip install transformers
# !pip install tensorflow
# Out:
# Requirement already satisfied: transformers in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (4.7.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (2021.10.23)
# Requirement already satisfied: huggingface-hub==0.0.8 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (0.0.8)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: sacremoses in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (0.0.46)
# Requirement already satisfied: pyyaml in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: packaging in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (21.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (1.21.3)
# Requirement already satisfied: requests in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from transformers) (2.26.0)
# Requirement already satisfied: colorama in c:\users\nishu\appdata\roaming\python\python39\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from packaging->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: joblib in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in c:\users\nishu\appdata\roaming\python\python39\site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: tensorflow in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (3.19.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\nishu\appdata\roaming\python\python39\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nishu\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorflow) (1.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.3.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.16.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nishu\anaconda3\envs\haystack\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization", model="t5-base")

# %%
text = "Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy."

# %%
summarizer(text, min_length=25, max_length=100)
# Out:
# Your max_length is set to 100, but you input_length is only 42. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# [{'summary_text': 'machine learning is a branch of artificial intelligence (AI) and computer science . it focuses on the use of data and algorithms to imitate the way humans learn .'}]
